# %%
pip install xgboost
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, precision_recall_curve, roc_curve, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn.multioutput import MultiOutputClassifier
import ast

device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"Training on device: {device}")

# Load data
df_train = pd.read_csv("../codebert/train_data.csv")
df_test = pd.read_csv("../codebert/test_data.csv")
X_train = torch.load("../codebert/X_train.pt", weights_only=False)
X_test = torch.load("../codebert/X_test.pt", weights_only=False)

def process_vulnerability_list(vuln_list_series, num_classes=9):
    vuln_lists = vuln_list_series.apply(ast.literal_eval)
    y_binary = np.array([np.array(vuln) for vuln in vuln_lists], dtype=np.float32)
    if y_binary.shape[1] != num_classes:
        raise ValueError(f"Expected {num_classes} dimensions, got {y_binary.shape[1]}")
    return torch.tensor(y_binary, dtype=torch.float32)

y_train = process_vulnerability_list(df_train['vulnerability_list'], num_classes=9)
y_test = process_vulnerability_list(df_test['vulnerability_list'], num_classes=9)
torch.save(y_train, "../codebert/y_train.pt")
torch.save(y_test, "../codebert/y_test.pt")

# 驗證形狀
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# Training on device: mps
# X_train shape: torch.Size([4794, 768])
# y_train shape: torch.Size([4794, 9])
# X_test shape: torch.Size([574, 768])
# y_test shape: torch.Size([574, 9])

# %%
class VulnScreener(nn.Module):
    def __init__(self):
        super(VulnScreener, self).__init__()
        self.mlp = nn.Sequential(
            nn.Linear(768, 256),  # Input layer to Hidden Layer 1
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 128),  # Hidden Layer 1 to Hidden Layer 2
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 1),    # Hidden Layer 2 to Output Layer
            nn.Sigmoid()          # Probability output
        )
    
    def forward(self, x):
        return self.mlp(x)  # Forward pass through the network

# Load screener probabilities
screener = torch.load("../codebert/vuln_screener_model.pth", weights_only=False)
screener.to(device)
screener.eval()
with torch.no_grad():
    train_prob = screener(X_train.to(device))
    test_prob = screener(X_test.to(device))

# %%
# MLP Model
class MLP(nn.Module):
    def __init__(self, input_dim=769, hidden_dim=256, output_dim=128, dropout_rate=0.3):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim // 2)
        self.fc3 = nn.Linear(hidden_dim // 2, output_dim)
        self.output_head = nn.Linear(output_dim, 9)  # For training MLP
        self.sigmoid = nn.Sigmoid()

    def forward(self, x, p_s):
        if p_s.dim() == 1:
            p_s = p_s.unsqueeze(1)
        x = torch.cat([x, p_s], dim=1)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        x = self.relu(x)
        x = self.dropout(x)
        features = self.fc3(x)  # Extracted features
        logits = self.output_head(features)  # For MLP training
        probs = self.sigmoid(logits)
        return features, probs

# Train MLP
def train_mlp(X_train, p_s_train, y_train, epochs=100):
    model = MLP().to(device)
    
    # Class-weighted BCE Loss
    class_counts = y_train.sum(dim=0)
    total_samples = y_train.shape[0]
    class_weights = total_samples / (9 * class_counts + 1e-6)
    criterion = nn.BCELoss(weight=class_weights.to(device))
    optimizer = optim.Adam(model.parameters(), lr=0.0001, weight_decay=0.1)
    
    X_train, p_s_train, y_train = X_train.to(device), p_s_train.to(device), y_train.to(device)
    
    for epoch in range(epochs):
        model.train()
        optimizer.zero_grad()
        
        features, probs = model(X_train, p_s_train)
        loss = criterion(probs, y_train)
        
        with torch.no_grad():
            y_pred_binary = (probs > 0.5).float()
            correct = (y_pred_binary == y_train).float().sum()
            total = y_train.numel()
            train_acc = correct / total
        
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        
        if epoch % 10 == 0:
            print(f"Epoch {epoch}, Loss: {loss.item():.4f}, Train Acc: {train_acc.item():.4f}")
    
    return model

# Extract features with trained MLP
def extract_features(model, X, p_s):
    model.eval()
    X, p_s = X.to(device), p_s.to(device)
    with torch.no_grad():
        features, _ = model(X, p_s)
    return features.cpu().numpy()

# Train and evaluate hybrid model
mlp_model = train_mlp(X_train, train_prob, y_train)
X_train_features = extract_features(mlp_model, X_train, train_prob)
X_test_features = extract_features(mlp_model, X_test, test_prob)
# Out:
# Epoch 0, Loss: 1.8768, Train Acc: 0.4166
# Epoch 10, Loss: 1.7364, Train Acc: 0.6328
# Epoch 20, Loss: 1.5792, Train Acc: 0.6980
# Epoch 30, Loss: 1.3936, Train Acc: 0.7366
# Epoch 40, Loss: 1.1820, Train Acc: 0.7774
# Epoch 50, Loss: 0.9631, Train Acc: 0.8229
# Epoch 60, Loss: 0.7665, Train Acc: 0.8533
# Epoch 70, Loss: 0.6019, Train Acc: 0.8643
# Epoch 80, Loss: 0.4869, Train Acc: 0.8678
# Epoch 90, Loss: 0.4316, Train Acc: 0.8694
# Epoch 100, Loss: 0.4153, Train Acc: 0.8687
# Epoch 110, Loss: 0.4157, Train Acc: 0.8698
# Epoch 120, Loss: 0.4154, Train Acc: 0.8724
# Epoch 130, Loss: 0.4175, Train Acc: 0.8723
# Epoch 140, Loss: 0.4167, Train Acc: 0.8717
# Epoch 150, Loss: 0.4168, Train Acc: 0.8700
# Epoch 160, Loss: 0.4127, Train Acc: 0.8719
# Epoch 170, Loss: 0.4104, Train Acc: 0.8719
# Epoch 180, Loss: 0.4128, Train Acc: 0.8729
# Epoch 190, Loss: 0.4126, Train Acc: 0.8728

# %%
# Train XGBoost on MLP features
xgb_model = MultiOutputClassifier(xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
    scale_pos_weight=5,
    max_depth=6,
    learning_rate=0.1,
    n_estimators=200,
    random_state=42
))
xgb_model.fit(X_train_features, y_train.numpy())

# Predict probabilities
y_pred_proba = np.array([est.predict_proba(X_test_features)[:, 1] for est in xgb_model.estimators_]).T

# Compute optimal thresholds
n_classes = y_test.shape[1]
optimal_thresholds = []
for i in range(n_classes):
    precision, recall, thresholds = precision_recall_curve(y_test[:, i], y_pred_proba[:, i])
    valid_idx = np.where(recall[:-1] >= 0.7)[0]
    optimal_threshold = thresholds[valid_idx[np.argmax(precision[valid_idx])]] if len(valid_idx) > 0 else 0.5
    optimal_thresholds.append(optimal_threshold)

# Apply thresholds
y_pred_binary = np.zeros_like(y_pred_proba)
for i in range(n_classes):
    y_pred_binary[:, i] = (y_pred_proba[:, i] >= optimal_thresholds[i]).astype(int)

# %%
# Compute metrics
metrics = {
    'avg_precision': precision_score(y_test, y_pred_binary, average='micro'),
    'avg_recall': recall_score(y_test, y_pred_binary, average='micro'),
    'avg_f1': f1_score(y_test, y_pred_binary, average='micro'),
    'avg_auc': roc_auc_score(y_test, y_pred_proba, average='micro'),
    'optimal_thresholds': optimal_thresholds
}

class_metrics = {
    'precision': precision_score(y_test, y_pred_binary, average=None),
    'recall': recall_score(y_test, y_pred_binary, average=None),
    'f1': f1_score(y_test, y_pred_binary, average=None),
    'auc': [roc_auc_score(y_test[:, i], y_pred_proba[:, i]) for i in range(n_classes)]
}
metrics['class_metrics'] = class_metrics

# %%
# Plot Precision-Recall Curves
plt.figure(figsize=(12, 8))
for i in range(n_classes):
    precision, recall, _ = precision_recall_curve(y_test[:, i], y_pred_proba[:, i])
    plt.plot(recall, precision, label=f'Class {i} (Opt. Threshold: {optimal_thresholds[i]:.3f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve per Class')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot ROC Curves
plt.figure(figsize=(12, 8))
for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test[:, i], y_pred_proba[:, i])
    auc_score = roc_auc_score(y_test[:, i], y_pred_proba[:, i])
    plt.plot(fpr, tpr, label=f'Class {i} (AUC: {auc_score:.3f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve per Class')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Confusion Matrices
plt.figure(figsize=(15, 15))
for i in range(n_classes):
    cm = confusion_matrix(y_test[:, i], y_pred_binary[:, i])
    plt.subplot(3, 3, i+1)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f'Class {i} Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
plt.tight_layout()
plt.show()

# %%
# Print results
print("\n=== MLP + XGBoost Test Results (Optimal Thresholds) ===")
print(f"Test Samples: {len(X_test)}")
print(f"Average Precision: {metrics['avg_precision']:.4f}")
print(f"Average Recall: {metrics['avg_recall']:.4f}")
print(f"Average F1-Score: {metrics['avg_f1']:.4f}")
print(f"Average AUC: {metrics['avg_auc']:.4f}")

print("\nPer-Class Metrics with Optimal Thresholds:")
for i in range(n_classes):
    print(f"\nVulnerability {i} (Threshold: {optimal_thresholds[i]:.3f}):")
    print(f"Precision: {class_metrics['precision'][i]:.4f}")
    print(f"Recall: {class_metrics['recall'][i]:.4f}")
    print(f"F1-Score: {class_metrics['f1'][i]:.4f}")
    print(f"AUC: {class_metrics['auc'][i]:.4f}")

print("\nSample Probabilities (first 5):", y_pred_proba[:5])
# Out:
# === MLP + XGBoost Test Results (Optimal Thresholds) ===
# Test Samples: 574
# Average Precision: 0.4354
# Average Recall: 0.7070
# Average F1-Score: 0.5389
# Average AUC: 0.9379
#
# Per-Class Metrics with Optimal Thresholds:
#
# Vulnerability 0 (Threshold: 0.927):
# Precision: 0.9286
# Recall: 0.7027
# F1-Score: 0.8000
# AUC: 0.9236
#
# Vulnerability 1 (Threshold: 0.052):
# Precision: 0.5439
# Recall: 0.7045
# F1-Score: 0.6139
# AUC: 0.9316
#
# Vulnerability 2 (Threshold: 0.000):
# Precision: 0.0366
# Recall: 0.7778
# F1-Score: 0.0700
# AUC: 0.7473
#
# Vulnerability 3 (Threshold: 0.000):
# Precision: 0.0366
# Recall: 0.7778
# F1-Score: 0.0700
# AUC: 0.7473
#
# Vulnerability 4 (Threshold: 0.028):
# Precision: 0.2653
# Recall: 0.7222
# F1-Score: 0.3881
# AUC: 0.9176
#
# Vulnerability 5 (Threshold: 0.151):
# Precision: 0.4158
# Recall: 0.7000
# F1-Score: 0.5217
# AUC: 0.8779
#
# Vulnerability 6 (Threshold: 0.452):
# Precision: 0.7292
# Recall: 0.7071
# F1-Score: 0.7179
# AUC: 0.9139
#
# ...
